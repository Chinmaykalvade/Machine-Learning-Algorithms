# %%
# Importing Libraries
import pandas as pd 
import numpy as np

# %%
# Reading dataset and I have renamed the dataset to movie_data from exp_06_input
df=pd.read_csv("movie_data.csv")

# %%
df.head()
# Out:
#                                               movies  1648  5136  918  2824  \
# 0      11: Star Wars: Episode IV - A New Hope (1977)   NaN   4.5  5.0   4.5
# 1                            12: Finding Nemo (2003)   NaN   5.0  5.0   NaN
# 2                            13: Forrest Gump (1994)   NaN   5.0  4.5   5.0
# 3                         14: American Beauty (1999)   NaN   4.0  NaN   NaN
# 4  22: Pirates of the Caribbean: The Curse of the...   4.0   5.0  3.0   4.5
#
#    3867  860  3712  2968  3525  ...   3556  5261  2492  5062  2486  4942  \
# 0   4.0  4.0   NaN   5.0   4.0  ...    4.0   NaN   4.5   4.0   3.5   NaN
# 1   4.0  4.0   4.5   4.5   4.0  ...    4.0   NaN   3.5   4.0   2.0   3.5
# 2   4.5  4.5   NaN   5.0   4.5  ...    4.0   5.0   3.5   4.5   4.5   4.0
# 3   NaN  NaN   4.5   2.0   3.5  ...    4.0   NaN   3.5   4.5   3.5   4.0
# 4   4.0  2.5   NaN   5.0   3.0  ...    3.0   1.5   4.0   4.0   2.5   3.5
#
#    2267  4809  3853  2288
# 0   NaN   NaN   NaN   NaN
# ...

# %%
# Taking the name of movies to filter
names=df['movies'].values

# %%
# Removing the number which is in the beginning of every movie to improve readability
l=[]
for name in names:
    for j in range (len(name)):
        if name[j]==":":
            l.append(name[j+1:])
            break

# %%
# Stripping Unnecessary spaces
l=[name.strip(' ') for name in l]
len(l)
# Out:
# 100

# %%
# Replacing old column with cleaned values
df.movies=l

# %%
df.head()
# Out:
#                                               movies  1648  5136  918  2824  \
# 0          Star Wars: Episode IV - A New Hope (1977)   NaN   4.5  5.0   4.5
# 1                                Finding Nemo (2003)   NaN   5.0  5.0   NaN
# 2                                Forrest Gump (1994)   NaN   5.0  4.5   5.0
# 3                             American Beauty (1999)   NaN   4.0  NaN   NaN
# 4  Pirates of the Caribbean: The Curse of the Bla...   4.0   5.0  3.0   4.5
#
#    3867  860  3712  2968  3525  ...   3556  5261  2492  5062  2486  4942  \
# 0   4.0  4.0   NaN   5.0   4.0  ...    4.0   NaN   4.5   4.0   3.5   NaN
# 1   4.0  4.0   4.5   4.5   4.0  ...    4.0   NaN   3.5   4.0   2.0   3.5
# 2   4.5  4.5   NaN   5.0   4.5  ...    4.0   5.0   3.5   4.5   4.5   4.0
# 3   NaN  NaN   4.5   2.0   3.5  ...    4.0   NaN   3.5   4.5   3.5   4.0
# 4   4.0  2.5   NaN   5.0   3.0  ...    3.0   1.5   4.0   4.0   2.5   3.5
#
#    2267  4809  3853  2288
# 0   NaN   NaN   NaN   NaN
# ...

# %%
# setting movies as index
df.set_index('movies',inplace=True)

# %%
df.head()
# Out:
#                                                     1648  5136  918  2824  \
# movies
# Star Wars: Episode IV - A New Hope (1977)            NaN   4.5  5.0   4.5
# Finding Nemo (2003)                                  NaN   5.0  5.0   NaN
# Forrest Gump (1994)                                  NaN   5.0  4.5   5.0
# American Beauty (1999)                               NaN   4.0  NaN   NaN
# Pirates of the Caribbean: The Curse of the Blac...   4.0   5.0  3.0   4.5
#
#                                                     3867  860  3712  2968  \
# movies
# Star Wars: Episode IV - A New Hope (1977)            4.0  4.0   NaN   5.0
# Finding Nemo (2003)                                  4.0  4.0   4.5   4.5
# Forrest Gump (1994)                                  4.5  4.5   NaN   5.0
# American Beauty (1999)                               NaN  NaN   4.5   2.0
# Pirates of the Caribbean: The Curse of the Blac...   4.0  2.5   NaN   5.0
#
# ...

# %%
# setting name for columns
df.columns.names=['userId']

# %%
# Taking transpose of dataset to find correlation
df=df.transpose()

# %%
df.head()
# Out:
# movies  Star Wars: Episode IV - A New Hope (1977)  Finding Nemo (2003)  \
# userId
# 1648                                          NaN                  NaN
# 5136                                          4.5                  5.0
# 918                                           5.0                  5.0
# 2824                                          4.5                  NaN
# 3867                                          4.0                  4.0
#
# movies  Forrest Gump (1994)  American Beauty (1999)  \
# userId
# 1648                    NaN                     NaN
# 5136                    5.0                     4.0
# 918                     4.5                     NaN
# 2824                    5.0                     NaN
# 3867                    4.5                     NaN
#
# movies  Pirates of the Caribbean: The Curse of the Black Pearl (2003)  \
# userId
# 1648                                                  4.0
# 5136                                                  5.0
# ...

# %%
# filling NaN with zeros
df.fillna(0,inplace=True)

# %%
# extracting ratings of a particular movie eg.Forest Gump
forrest_gump_ratings = df['Forrest Gump (1994)']
forrest_gump_ratings.head()
# Out:
# userId
# 1648    0.0
# 5136    5.0
# 918     4.5
# 2824    5.0
# 3867    4.5
# Name: Forrest Gump (1994), dtype: float64

# %%
# finding correlation of forest gump with other movies
movies_like_forest_gump = df.corrwith(forrest_gump_ratings)
movies_like_forest_gump.head()
# Out:
# movies
# Star Wars: Episode IV - A New Hope (1977)                        0.445237
# Finding Nemo (2003)                                              0.182646
# Forrest Gump (1994)                                              1.000000
# American Beauty (1999)                                           0.020644
# Pirates of the Caribbean: The Curse of the Black Pearl (2003)    0.334885
# dtype: float64

# %%
# making a dataframe of movies like forest Gump
corr_forrest_gump = pd.DataFrame(movies_like_forest_gump, columns=['Correlation'])  
corr_forrest_gump.dropna(inplace=True)  
corr_forrest_gump.head()
# Out:
#                                                     Correlation
# movies
# Star Wars: Episode IV - A New Hope (1977)              0.445237
# Finding Nemo (2003)                                    0.182646
# Forrest Gump (1994)                                    1.000000
# American Beauty (1999)                                 0.020644
# Pirates of the Caribbean: The Curse of the Blac...     0.334885

# %%
# sorting the dataset to list most similar movies like forest Gump
# top 5 similar movies like Forest Gump
corr_forrest_gump.sort_values('Correlation', ascending=False).head(5)
# Out:
#                                                    Correlation
# movies
# Forrest Gump (1994)                                   1.000000
# Fight Club (1999)                                     0.530641
# The Shawshank Redemption (1994)                       0.524413
# Gladiator (2000)                                      0.517887
# Star Wars: Episode VI - Return of the Jedi (1983)     0.472852
